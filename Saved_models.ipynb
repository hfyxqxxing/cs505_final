# %% [markdown]
# # GPT2

# %%
import os
import time
import datetime
# from google.colab import drive

import pandas as pd
import seaborn as sns
import numpy as np
import random

import matplotlib.pyplot as plt

import torch
from torch.utils.data import Dataset, DataLoader, random_split, RandomSampler, SequentialSampler
torch.manual_seed(42)

from transformers import GPT2LMHeadModel,  GPT2Tokenizer, GPT2Config, GPT2LMHeadModel
from transformers import AdamW, get_linear_schedule_with_warmup

from datasets import load_dataset
import torch
from tqdm import tqdm


output_dir = './model_save_GPT/'

model = GPT2LMHeadModel.from_pretrained(output_dir).cuda()

tokenizer = GPT2Tokenizer.from_pretrained(output_dir)

device = torch.device("cuda")
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
# Get all of the model's parameters as a list of tuples.
params = list(model.named_parameters())

print('The GPT-2 model has {:} different named parameters.\n'.format(len(params)))

print('==== Embedding Layer ====\n')

for p in params[0:2]:
    print("{:<55} {:>12}".format(p[0], str(tuple(p[1].size()))))

print('\n==== First Transformer ====\n')

for p in params[2:14]:
    print("{:<55} {:>12}".format(p[0], str(tuple(p[1].size()))))

print('\n==== Output Layer ====\n')

for p in params[-2:]:
    print("{:<55} {:>12}".format(p[0], str(tuple(p[1].size()))))
# Out:
# The GPT-2 model has 148 different named parameters.
#
# ==== Embedding Layer ====
#
# transformer.wte.weight                                  (50259, 768)
# transformer.wpe.weight                                   (1024, 768)
#
# ==== First Transformer ====
#
# transformer.h.0.ln_1.weight                                   (768,)
# transformer.h.0.ln_1.bias                                     (768,)
# transformer.h.0.attn.c_attn.weight                       (768, 2304)
# transformer.h.0.attn.c_attn.bias                             (2304,)
# transformer.h.0.attn.c_proj.weight                        (768, 768)
# transformer.h.0.attn.c_proj.bias                              (768,)
# transformer.h.0.ln_2.weight                                   (768,)
# transformer.h.0.ln_2.bias                                     (768,)
# transformer.h.0.mlp.c_fc.weight                          (768, 3072)
# transformer.h.0.mlp.c_fc.bias                                (3072,)
# transformer.h.0.mlp.c_proj.weight                        (3072, 768)
# transformer.h.0.mlp.c_proj.bias                               (768,)
#
# ==== Output Layer ====
#
# transformer.ln_f.weight                                       (768,)
# transformer.ln_f.bias                                         (768,)

# %% [markdown]
# # Generate Text

# %%
model.eval()

# Change the noun between the = = signs. We kept this in data so it is a symbol of word to be explained
prompt = "<|startoftext|> = Soap = :"

generated = torch.tensor(tokenizer.encode(prompt)).unsqueeze(0)
generated = generated.to(device)

print(generated)

sample_outputs = model.generate(
                                generated,
                                do_sample=True,
                                top_k=1000,
                                max_length = 1000,
                                top_p=2,
                                num_return_sequences=3
                                )

for i, sample_output in enumerate(sample_outputs):
  print("{}: {}\n\n".format(i, tokenizer.decode(sample_output, skip_special_tokens=True)))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# tensor([[50257,   796,  1406,   499,   796,  1058]], device='cuda:0')
# 0:  = Soap = : Post-fire microorganisms again have a long and rich history in the environment, now characterized by few neighbors. scale spores areolate, allowing for specific prey influx
#  fungi to grow with Earthworms and suck up flowers. In the absence of microorganisms, the pathogenic spores multiply and slow to find new host cells. The fungus's function depends on the host species being present for a given area, but a strong affinity for the microorganisms has been observed for defense purposes. The fungus grows on far deeper ground than the native forest, but the strength of its mushroom invasion depends on the availability of suitable substrates.  A similar rapid growth event may be found with soil plumes, which are warmer than with artificial stagnant air. Widespread reduced temperature and other seasonal influences, such as moisture and humidity, can increase fungus activity. The insects consume organic matter and expel secondary particles from the soil, often forming spores supporting basic grass roots and spruce, especially in larger and larger subspecies of this type.  Many yeast, mainly housed in microferments, are " stained'green ", suggesting that a widespread influx of stink fungus into the environment may also encode the odor of the soil. Reactions with stink items alter the appearance of the stink plaque. The odor odor may be generated by the small scythe swelling in the small bowel, and may also be generated by outside stimuli, such as fungus. The absence of bromine sugars that are often associated with memory are probably caused due to the mechanism by which the fungus generates new substrate or growth factors. Holistic soils have been associated with protection from fungus spores.  The central aisle ( where the insects feed ) tends to be more numerous ( so close to the headline and footnotes points in the line ) as well as more rapidly spreading, which could cause grass that is either in hot or humid areas to scatter spores across the substrate between areas. This may be attributed to the same underlying mechanism that binds rapid pecking in such soil. Furthermore, the treebodies may not react to odor from outside sources, and parasitic odor is unrelated to ambient ticks. Many microorganisms survived for many years on microhabitats in the United States, although health care workers found associations with antifungal or cereal grain infections throughout the United States. Some of these infections were associated with microscopic spores that were subsequently labelled as anti-inflammatory proteins.
#
#
# 1:  = Soap = : Lambdas and sulfur panes are made from organic matter ( Lactobacillus acidophiles ) similarly that polyacrylamide is used as an anti-bacterial agent in the pathogenic Borrelia burgdorferi fungus.  Topically agitating oak ( 1 cm2 ) or citric acid ( 1.4 m3 ) seedlings are grown in the oak ( i.e. arid or humid ) plots, the germination of the hybrid seedling is controlled by agar ( i.e. hard and thin ) agar ( the type used ). The jatropha formed by the chiric-vinegar ( cologne ) is an important indicator of how well the agar is handled in the production of oatcakes. The " edible " flavored oatbakes have a similar kind of flavor, usually portraying vignettes of the botanist who removed the granules. In addition, organic acids are used. The oils used ( cream, bicarbonate, and arctic fat ) are free from sulfur compounds and the skarns and pine fragrances sold by the botanical thattainers are powered-in-the-kerosene ( K-K-T, or tamarind organic ).  A hybrid starter is made of 200 ppm organic acid and 1,400 ppm Lactobacillus acidophiles or polyacrylamides to stimulate the formation of good-for-you bubbles. All three species of fruiting bodies are grown in a single log, differentiated by their respective spores ( spores 2, 4, 7 and 10 ) after maturity. The photoserver of the individual brusified egg does not contain onkrasen cells but contains at least 1,900 chlorinated flint,lues, and white-intoxicating octahedral structures arranged in parallel. Several others are pricked by buffered carbenes. Treating your lower 52 ° F with 100 ppm organic acid will correct the buffering if ruminative acid is drained ( 80 ° F ) from inside the container.
#
#
# 2:  = Soap = : Synthetic acid ( 0.5 % ) is derived from Wysockiaceae. It can be present in many forms and compounds. Allantoin, astringents, drugs, and veterinary care are all approved by the Food and Drug Administration.  High amounts of tyrosine kinase inhibitors, including 3,6-dimethylsulfonylacetate and 3,4-lactone, associate with increased risk of E.coli infection. tyrosine kinase inhibitors ( if necessary ) can lead to injury to the liver and the expression of enzymes involved in platelets, which could increase the risk of E.coli. sulfur-oxosulfonic acid is well known for its high biotrophic activity. Its recommended daily consumption is 2.4 g ( 17.8 oz ), and the daily availability depends on how frequently those meals are prepared ; young women are recommended to eat 2.4 g ( 17.8 oz ) to achieve a healthy blood pressure. Sulfones are biotrophic. i.e. their cell culture appears as a dry nucleophilic state  Sulfyl proccharide inhibits polypeptide exchange enzymes and inhibits polyesteryltransferase activity in cell lines ( S raucus ferrets ). splenocytes are introduced into their host cells, which harbor the drug epoxoalbumins ; however, many lectins are being developed for this purpose.  The sulfoamine receptor 3 is an absence of inhibitory pathways. sodium aziridines are sulfone salts that accumulate in the liver where their nonspecific effects by antifungal compounds are blocked.  The tyrosine-amine kinase inhibitors ( if necessary ) are associated with increased risk of E. coli pilocarpalosa infection, which could lead to the development of acute colitis. Furthermore, even when the drugs are ineffective, side effects may occur.  Hispanopods are polypropyl –hydroxyindolen-sulfopolantinone 4 (PAH3 ) monomer with a low molecular weight, similar strength, and odorless taste. Preuse of benzaldehyde is approved, but can cause liver damage appearing almost immediately and can also cause fatigue. Benzone has also been shown to increase the risk of E. syncope and aggressive stroke.

# %% [markdown]
# Perplexity

# %%
max_length = model.config.n_positions
stride = 512

def ppl(model, input_ids_all, stride):
  nlls = []
  for i in tqdm(range(0, input_ids_all.size(1), stride)):
      begin_loc = max(i + stride - max_length, 0)
      end_loc = min(i + stride, input_ids_all.size(1))
      trg_len = end_loc - i  # may be different from stride on last loop
      input_ids = input_ids_all[:, begin_loc:end_loc].to("cuda:0")
      target_ids = input_ids.clone()
      target_ids[:, :-trg_len] = -100

      with torch.no_grad():
          outputs = model(input_ids, labels=target_ids)
          neg_log_likelihood = outputs[0] * trg_len

      nlls.append(neg_log_likelihood)

  ppl = torch.exp(torch.stack(nlls).sum() / end_loc)
  return ppl

# %%
import json
with open("./data/test.json", "r") as json_file:
    dealt_test = json.load(json_file)

# %%
encodings = tokenizer("\n\n".join(dealt_test), return_tensors="pt")
ppl(model, encodings.input_ids, stride)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (277118 > 1024). Running this sequence through the model will result in indexing errors
# 100%|██████████| 542/542 [00:33<00:00, 16.26it/s]
# tensor(46.0095, device='cuda:0')

# %% [markdown]
# # BioGPT

# %%
import os
import time
import datetime
# from google.colab import drive

import pandas as pd
import seaborn as sns
import numpy as np
import random

import matplotlib.pyplot as plt

import torch
from torch.utils.data import Dataset, DataLoader, random_split, RandomSampler, SequentialSampler


from transformers import AdamW, get_linear_schedule_with_warmup
from transformers import AutoTokenizer, BioGptForCausalLM

# %%
output_dir = './model_save_Bio/'

model = BioGptForCausalLM.from_pretrained(output_dir).cuda()

tokenizer = AutoTokenizer.from_pretrained(output_dir)

device = torch.device("cuda")
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
model.eval()

prompt = "<|startoftext|> = Soap = :"

generated = torch.tensor(tokenizer.encode(prompt)).unsqueeze(0)
generated = generated.to(device)

print(generated)

sample_outputs = model.generate(
                                generated,
                                do_sample=True,
                                top_k=1000,
                                max_length = 1000,
                                top_p=2,
                                num_return_sequences=3
                                )

for i, sample_output in enumerate(sample_outputs):
  print("{}: {}\n\n".format(i, tokenizer.decode(sample_output, skip_special_tokens=True)))
# Out:
# tensor([[    2, 42384,    43, 10583,  8081,    43,    20]], device='cuda:0')
# 0: = Soap =: Soap is the sixth annual "railroad in Southern California, the largest city on the Kakapo River in the United States." The nineteenth named road in Southern California in the 18th century, it spread northeastward to eastern Washington, including the Corn Exchange. Due to the combined population of the Kakapo River and the Kakapo River, the area was annexed by the Mustang people as early as the 18th century. A railroad between the Gulf of Mexico and Kakapo was established in 1851, using the South Pacific Railroad as its eastern boundary. These changes made the area more populated by Europeans, and yielded many northern turns. Today, the railway is primarily used for rail traffic and road heads by European and French natives. an Soap, Soap is given a Soap, Inc. The size, the decision by taxed locally, Star of the area declarations of the time, the original belt, the U.S. Fish and of the area declaration of the Kakapo 'Imagination by native and build Pudson River arose, the 1837, ification on the early on the brawrecy of the route of Reef River in the area and of Kakiu Lofai, however t Tracking and Engineer River from 1972, and of desk the same plan a trail donated by 1966 ification and Human Development and Interior engineer Boat the Kakiu thrite, including the Palespounder this area declaration in future. Boat Withers following this area mechanize the motivated by remarked by the wake of the cougar, the time fleet. The Arden
#
#
# 1: = Soap =: The Soap is a political thriller. It was first introduced by independent church government in the 1930s and 1940s. It produced moderate political convention in 1956 and repeated in power following the Soap. Since the 1940s and 1960s, many of Rome's music regularly changed hands with the Soap and the Soap since its 1970 session. It was followed by the Soap operatives that carried masteries from the 1940s to the present. The music had pace and precision, with the change in the 1950s and 1960s merging into one of the largest music in Southern Europe. Back in Birmingham, the music regularly gained notice in the 1970s and 1980s, and reached major positions in Belgium. The Soap opera was still in existence but came to be banned by dictatorships, governmental and military regime changes. By 1974 the country has hosted about 300 street music fights, Crocodile playing in the 1960s, and restored to a major musical festival in 2005 at Katia, installing two concerts with the Crocodile Remaker in downtown Katia and one singer in the jungle Bremen' s National Opera House. gro 15 being Home Fire 'Soap' Operation Operation Operation Operation (41), the Tour soap opera were taken from this time. Unite Soap. These Times Drake frozen, this time being in 2007, as Soap opera 'Immigration of competition a civilian website, once, with its seize in September 1, with a head of the Soap provided by three local kartwork-woman and-a rant-a' Imonstage international of aircraft, Soap, With 95 Among sein the 2013 F
#
#
# 2: = Soap =: Soap opera The Simpsons is a high-profile television show made possible and published by the NBC. The show follows the life of Tina Nielsen (the fourth tier of the Butterfly Lossip) who is sent to resign in a non-playing role, visiting a pre-production company in Hear My Song which is now Chess and the heir to succeed. In the 1970s, Nielsen was adjusting the supernatural character to Tina Fey, and with this new relationship, Michaels Junior, president of the show, decided that the show is interested in creating a relationship with Tina and Hear. Water traffic was carried out of Brunswick University before handing the Wang-Mart commercial in 2001. a ratings for public down, Brains criization a froth episode of hot peppers, set in the show during such a daily Pau-held in November 2002 at Gabalyze Age announcement, Pomet bombs Among You, "From UFO Hot" ("Toward the Jump Street Hae"), "ensued initially," ("(Artistic is given given given the day", ", known at the Ken Soap" (")" (Jump Jung Du Haa little Tah "(Murder of Spee" ("(Art" (Gone of All if ") and UFO members)" ("(Named" (Get Us "(The Father Other than)" (Lover

# %%
max_length = model.config.max_position_embeddings
stride = 512

def ppl(model, input_ids_all, stride):
  nlls = []
  for i in tqdm(range(0, input_ids_all.size(1), stride)):
      begin_loc = max(i + stride - max_length, 0)
      end_loc = min(i + stride, input_ids_all.size(1))
      trg_len = end_loc - i  # may be different from stride on last loop
      input_ids = input_ids_all[:, begin_loc:end_loc].to("cuda:0")
      target_ids = input_ids.clone()
      target_ids[:, :-trg_len] = -100

      with torch.no_grad():
          outputs = model(input_ids, labels=target_ids)
          neg_log_likelihood = outputs[0] * trg_len

      nlls.append(neg_log_likelihood)

  ppl = torch.exp(torch.stack(nlls).sum() / end_loc)
  return ppl

# %%
import json
with open("./data/test.json", "r") as json_file:
    dealt_test = json.load(json_file)

# %%
encodings = tokenizer("\n\n".join(dealt_test), return_tensors="pt")
ppl(model, encodings.input_ids, stride)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (310653 > 1024). Running this sequence through the model will result in indexing errors
# 100%|██████████| 607/607 [01:29<00:00,  6.75it/s]
# tensor(451.4723, device='cuda:0')
